# %%
import numpy as np
import random
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

import numpy as np
import random
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from scipy import stats  # For statistical tests
import matplotlib.pyplot as plt  # For plotting (optional)
import math

# %%
## Data generator
centers = [
    [200000, 200000],  # Cluster 1
    [300000, 300000],  # Cluster 2
    [400000, 200000],  # Cluster 3
    [500000, 300000],  # Cluster 4
    [600000, 200000]   # Cluster 5
]

# Define standard deviations (similar to variance) for each cluster
cluster_std = [25000, 25000, 27000, 30000, 29000]  # These control spread of clusters

# Generate synthetic data
data, true_labels = make_blobs(n_samples=1000000, centers=centers, cluster_std=cluster_std, random_state=42)

# Compute center of mass for each cluster based on true labels
unique_labels = np.unique(true_labels)
centers_of_mass = np.array([np.mean(data[true_labels == label], axis=0) for label in unique_labels])

# Plot 1: Generated overlapping clusters with center of mass for each cluster
plt.figure(figsize=(10, 8))
scatter = plt.scatter(data[:, 0], data[:, 1], c=true_labels, cmap='viridis', s=10)
plt.colorbar(scatter)

# Plot the center of mass for each cluster
plt.scatter(centers_of_mass[:, 0], centers_of_mass[:, 1], color='red', marker='x', s=200, label='Center of Mass for Clusters')

# Add labels and grid
plt.title("Generated Overlapping Clusters with Center of Mass for Each Cluster")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.legend()
plt.show()

# %%
# Function to initialize centroids (same as before)
def initialize_centroids(data, k):
    n_samples, _ = data.shape
    centroids = []
    # Randomly select the first centroid
    centroids.append(data[random.randint(0, n_samples - 1)])

    # Array to store the minimum distances to the closest centroid
    distances = np.full(n_samples, np.inf)

    for _ in range(1, k):
        # Vectorized calculation of distances from all data points to the latest centroid
        new_distances = np.linalg.norm(data - centroids[-1], axis=1) ** 2

        # Update the minimum distances to the nearest centroid
        distances = np.minimum(distances, new_distances)

        # Compute probabilities proportional to the squared distances
        probabilities = distances / distances.sum()

        # Choose the next centroid randomly according to the probabilities
        cumulative_probabilities = np.cumsum(probabilities)
        r = random.random()
        index = np.searchsorted(cumulative_probabilities, r)
        centroids.append(data[index])

    return np.array(centroids)

# %%
def compute_potential(data, labels, centroids):
    potential = 0.0
    for i, centroid in enumerate(centroids):
        potential += np.sum((data[labels == i] - centroid) ** 2)
    return potential

# %%
def run_kmeans_and_compute_potential(data, k):
    # Initialize centroids using the vanilla K-means++ method
    initial_centroids = initialize_centroids(data, k)

    # Use custom centroids in KMeans
    kmeans = KMeans(n_clusters=k, init=initial_centroids, max_iter=300, n_init=1, random_state=42)
    kmeans.fit(data)
    
    final_centroids = kmeans.cluster_centers_
    final_labels = kmeans.labels_
    final_potential = compute_potential(data, final_labels, final_centroids)
    
    return final_potential, final_labels, final_centroids

# %%
k = len(centers)
num_trials = 2 ** k  # Number of trials

optimal_potential = compute_potential(data, true_labels, centers)

# Run 2^k trials and store the final potentials and clustering results
final_potentials = []
trial_labels = []
trial_centroids = []
for trial in range(num_trials):
    final_potential, final_labels, final_centroids = run_kmeans_and_compute_potential(data, k)
    final_potentials.append(final_potential)
    trial_labels.append(final_labels)
    trial_centroids.append(final_centroids)

# Normalize the final potentials by dividing them by the optimal potential
normalized_potentials = [fp / optimal_potential for fp in final_potentials]

# Plot 2: Line chart showing the normalized potentials for each trial
plt.figure(figsize=(10, 6))
plt.plot(range(num_trials), normalized_potentials, marker='o', linestyle='-', color='blue')
plt.axhline(y=1.0, color='red', linestyle='--', label="Optimal Potential (Normalized = 1)")
plt.title(f"Normalized Final Potentials across {num_trials} Trials")
plt.xlabel("Trial")
plt.ylabel("Normalized Final Potential (Final / Optimal)")
plt.legend()
plt.grid(True)
plt.show()

# Find the trial with the minimal potential
min_potential_index = np.argmin(final_potentials)
min_potential_labels = trial_labels[min_potential_index]
min_potential_centroids = trial_centroids[min_potential_index]

# Plot 3: K-means++: Clusters with Minimal Potential
plt.figure(figsize=(10, 8))
scatter = plt.scatter(data[:, 0], data[:, 1], c=min_potential_labels, cmap='viridis', s=10)
plt.scatter(min_potential_centroids[:, 0], min_potential_centroids[:, 1], color='red', marker='x', s=200, label='Centroids')
plt.colorbar(scatter)
plt.title("K-means++: Clusters with Minimal Potential")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Experiment 1
k_values = [3, 4, 5]
N = 30  # Number of datasets (repetitions)

# Dictionaries to store results for each k
mean_proportions = {}
std_proportions = {}
all_proportions = {}  # To store proportions for statistical tests

for k in k_values:
    print(f"\nRunning experiments for k = {k}")
    num_trials = 2 ** k  # Number of trials
    c = math.log(k)
    print(c)

    proportions = []  # To store success proportions for each dataset

    for dataset_num in range(N):
        # Generate random cluster centers and standard deviations
        centers = np.random.uniform(low=100000, high=600000, size=(k, 2))
        cluster_std = np.random.uniform(low=20000, high=30000, size=k)

        # Generate the data
        data, true_labels = make_blobs(n_samples=1000000, centers=centers, cluster_std=cluster_std, random_state=42)

        # Compute the optimal potential using true centers and true labels
        optimal_potential = compute_potential(data, true_labels, centers)

        constant_factor_count = 0  # Counter for constant-factor approximations in this dataset

        for trial in range(num_trials):
            # Initialize centroids and run KMeans
            initial_centroids = initialize_centroids(data, k)
            kmeans = KMeans(n_clusters=k, init=initial_centroids, max_iter=100, n_init=1, random_state=42)
            kmeans.fit(data)

            final_centroids = kmeans.cluster_centers_
            final_labels = kmeans.labels_
            final_potential = compute_potential(data, final_labels, final_centroids)

            normalized_potential = final_potential / optimal_potential

            # Check if the normalized potential is less than or equal to c
            if normalized_potential <= c:
                constant_factor_count += 1

        # Compute the success proportion for this dataset
        success_proportion = constant_factor_count / num_trials
        proportions.append(success_proportion)

        print(f"Dataset {dataset_num + 1}/{N} for k={k}: Success proportion = {success_proportion:.4f}")

    # Compute mean and standard deviation of success proportions for this k
    mean_proportion = np.mean(proportions)
    std_proportion = np.std(proportions, ddof=1)

    mean_proportions[k] = mean_proportion
    std_proportions[k] = std_proportion
    all_proportions[k] = proportions  # Store for statistical tests

    # Compute standard error
    SE = std_proportion / np.sqrt(N)

    # Construct confidence interval (e.g., 95% confidence interval)
    z = 1.96  # For 95% confidence
    CI_lower = mean_proportion - z * SE
    CI_upper = mean_proportion + z * SE

    print(f"\nFor k = {k}:")
    print(f"Mean success proportion: {mean_proportion:.4f}")
    print(f"Standard deviation: {std_proportion:.4f}")
    print(f"95% Confidence interval for the mean success proportion: [{CI_lower:.4f}, {CI_upper:.4f}]")

# At this point, you have mean_proportions and std_proportions dictionaries containing the results for k=3,4,5
# Out:
# Running experiments for k = 3
# 1.0986122886681098
# Dataset 1/30 for k=3: Success proportion = 1.0000
# Dataset 2/30 for k=3: Success proportion = 1.0000
# Dataset 3/30 for k=3: Success proportion = 0.6250
# Dataset 4/30 for k=3: Success proportion = 0.8750
# Dataset 5/30 for k=3: Success proportion = 0.7500
# Dataset 6/30 for k=3: Success proportion = 1.0000
# Dataset 7/30 for k=3: Success proportion = 0.8750
# Dataset 8/30 for k=3: Success proportion = 1.0000
# Dataset 9/30 for k=3: Success proportion = 1.0000
# Dataset 10/30 for k=3: Success proportion = 1.0000
# Dataset 11/30 for k=3: Success proportion = 1.0000
# Dataset 12/30 for k=3: Success proportion = 1.0000
# Dataset 13/30 for k=3: Success proportion = 1.0000
# Dataset 14/30 for k=3: Success proportion = 0.8750
# Dataset 15/30 for k=3: Success proportion = 0.7500
# Dataset 16/30 for k=3: Success proportion = 0.8750
# Dataset 17/30 for k=3: Success proportion = 1.0000
# Dataset 18/30 for k=3: Success proportion = 0.8750
# Dataset 19/30 for k=3: Success proportion = 1.0000
# Dataset 20/30 for k=3: Success proportion = 1.0000
# Dataset 21/30 for k=3: Success proportion = 0.7500
# Dataset 22/30 for k=3: Success proportion = 1.0000
# Dataset 23/30 for k=3: Success proportion = 1.0000
# Dataset 24/30 for k=3: Success proportion = 1.0000
# Dataset 25/30 for k=3: Success proportion = 1.0000
# Dataset 26/30 for k=3: Success proportion = 1.0000
# Dataset 27/30 for k=3: Success proportion = 1.0000
# Dataset 28/30 for k=3: Success proportion = 1.0000
# Dataset 29/30 for k=3: Success proportion = 1.0000
# Dataset 30/30 for k=3: Success proportion = 1.0000
#
# For k = 3:
# Mean success proportion: 0.9417
# Standard deviation: 0.1024
# 95% Confidence interval for the mean success proportion: [0.9050, 0.9783]
#
# Running experiments for k = 4
# 1.3862943611198906
# Dataset 1/30 for k=4: Success proportion = 1.0000
# Dataset 2/30 for k=4: Success proportion = 0.8125
# Dataset 3/30 for k=4: Success proportion = 1.0000
# Dataset 4/30 for k=4: Success proportion = 0.6875
# Dataset 5/30 for k=4: Success proportion = 0.7500
# Dataset 6/30 for k=4: Success proportion = 1.0000
# Dataset 7/30 for k=4: Success proportion = 1.0000
# Dataset 8/30 for k=4: Success proportion = 1.0000
# Dataset 9/30 for k=4: Success proportion = 1.0000
# Dataset 10/30 for k=4: Success proportion = 1.0000
# Dataset 11/30 for k=4: Success proportion = 1.0000
# Dataset 12/30 for k=4: Success proportion = 0.5000
# Dataset 13/30 for k=4: Success proportion = 0.8125
# Dataset 14/30 for k=4: Success proportion = 1.0000
# Dataset 15/30 for k=4: Success proportion = 0.7500
# Dataset 16/30 for k=4: Success proportion = 1.0000
# Dataset 17/30 for k=4: Success proportion = 1.0000
# Dataset 18/30 for k=4: Success proportion = 0.8125
# Dataset 19/30 for k=4: Success proportion = 1.0000
# Dataset 20/30 for k=4: Success proportion = 0.9375
# Dataset 21/30 for k=4: Success proportion = 1.0000
# Dataset 22/30 for k=4: Success proportion = 1.0000
# Dataset 23/30 for k=4: Success proportion = 0.7500
# Dataset 24/30 for k=4: Success proportion = 1.0000
# Dataset 25/30 for k=4: Success proportion = 1.0000
# Dataset 26/30 for k=4: Success proportion = 1.0000
# Dataset 27/30 for k=4: Success proportion = 0.8125
# Dataset 28/30 for k=4: Success proportion = 0.8750
# Dataset 29/30 for k=4: Success proportion = 0.9375
# Dataset 30/30 for k=4: Success proportion = 0.8125
#
# For k = 4:
# Mean success proportion: 0.9083
# Standard deviation: 0.1290
# 95% Confidence interval for the mean success proportion: [0.8622, 0.9545]
#
# Running experiments for k = 5
# 1.6094379124341003
# Dataset 1/30 for k=5: Success proportion = 1.0000
# Dataset 2/30 for k=5: Success proportion = 1.0000
# Dataset 3/30 for k=5: Success proportion = 1.0000
# Dataset 4/30 for k=5: Success proportion = 0.9375
# Dataset 5/30 for k=5: Success proportion = 1.0000
# Dataset 6/30 for k=5: Success proportion = 0.8750
# Dataset 7/30 for k=5: Success proportion = 1.0000
# Dataset 8/30 for k=5: Success proportion = 0.7500
# Dataset 9/30 for k=5: Success proportion = 1.0000
# Dataset 10/30 for k=5: Success proportion = 1.0000
# Dataset 11/30 for k=5: Success proportion = 0.9688
# Dataset 12/30 for k=5: Success proportion = 1.0000
# Dataset 13/30 for k=5: Success proportion = 0.8438
# Dataset 14/30 for k=5: Success proportion = 1.0000
# Dataset 15/30 for k=5: Success proportion = 0.9375
# Dataset 16/30 for k=5: Success proportion = 0.8438
# Dataset 17/30 for k=5: Success proportion = 1.0000
# Dataset 18/30 for k=5: Success proportion = 0.7500
# Dataset 19/30 for k=5: Success proportion = 0.8750
# Dataset 20/30 for k=5: Success proportion = 0.9062
# Dataset 21/30 for k=5: Success proportion = 1.0000
# Dataset 22/30 for k=5: Success proportion = 0.5938
# Dataset 23/30 for k=5: Success proportion = 0.7500
# Dataset 24/30 for k=5: Success proportion = 0.9688
# Dataset 25/30 for k=5: Success proportion = 1.0000
# Dataset 26/30 for k=5: Success proportion = 1.0000
# Dataset 27/30 for k=5: Success proportion = 0.9375
# Dataset 28/30 for k=5: Success proportion = 1.0000
# Dataset 29/30 for k=5: Success proportion = 1.0000
# Dataset 30/30 for k=5: Success proportion = 0.7500
#
# For k = 5:
# Mean success proportion: 0.9229
# Standard deviation: 0.1082
# 95% Confidence interval for the mean success proportion: [0.8842, 0.9616]

# %%
# statistical test for experiment 1

# Collect the success proportions for each k
proportions_k3 = all_proportions[3]
proportions_k4 = all_proportions[4]
proportions_k5 = all_proportions[5]

# Perform one-way ANOVA
F_statistic, p_value = stats.f_oneway(proportions_k3, proportions_k4, proportions_k5)

print("\nOne-way ANOVA results:")
print(f"F-statistic: {F_statistic:.4f}")
print(f"p-value: {p_value:.4f}")

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("The differences in mean success proportions across different k are statistically significant.")
else:
    print("No statistically significant differences were found in mean success proportions across different k.")

# If significant, perform post-hoc tests (Tukey's HSD)
# Since scipy doesn't have Tukey's HSD, we'll use statsmodels
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Prepare data for Tukey's HSD
data = proportions_k3 + proportions_k4 + proportions_k5
groups = (['k=3'] * N) + (['k=4'] * N) + (['k=5'] * N)
df = pd.DataFrame({'Success_Proportion': data, 'Group': groups})

# Perform Tukey's HSD test
tukey = pairwise_tukeyhsd(endog=df['Success_Proportion'], groups=df['Group'], alpha=0.05)

print("\nTukey's HSD test results:")
print(tukey)

# Optional: Plot the results
tukey.plot_simultaneous()
plt.title("Tukey HSD Test for Success Proportions Across k")
plt.xlabel("Success Proportion")
plt.show()
# Out:
# One-way ANOVA results:
# F-statistic: 0.6474
# p-value: 0.5259
# No statistically significant differences were found in mean success proportions across different k.
#
# Tukey's HSD test results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#    k=3    k=4  -0.0333 0.4953 -0.1034 0.0367  False
#    k=3    k=5  -0.0187 0.7994 -0.0888 0.0513  False
#    k=4    k=5   0.0146 0.8732 -0.0555 0.0846  False
# ---------------------------------------------------

# %%
## Experiment 2
k_values = [3, 4, 5]
N = 30  # Number of datasets (repetitions)
delta = 3  # Threshold for early stopping (three-sigma rule)


# Dictionaries to store results for each k
results = {}

for k in k_values:
    print(f"\nRunning experiments for k = {k}")
    N_min = k  # Minimum number of trials before checking early stopping
    N_max = 2 ** k  # Maximum number of trials
    c = math.log(k)
    print(c)

    early_stop_counts = []  # Number of trials before early stopping
    success_flags = []      # Whether a constant-factor approximation was achieved
    normalized_potentials_at_stop = []  # Normalized potentials at early stopping

    for dataset_num in range(N):
        print(f"Dataset {dataset_num + 1}/{N} for k={k}")
        # Generate random cluster centers and standard deviations
        centers = np.random.uniform(low=100000, high=600000, size=(k, 2))
        cluster_std = np.random.uniform(low=25000, high=30000, size=k)

        # Generate the data
        data, true_labels = make_blobs(n_samples=1000000, centers=centers, cluster_std=cluster_std, random_state=42)

        # Compute the optimal potential using true centers and true labels
        optimal_potential = compute_potential(data, true_labels, centers)

        # Initialize list to store normalized potentials
        normalized_potentials = []

        N_stop = 0  # Number of trials before early stopping
        success_flag = False  # Whether a constant-factor approximation was achieved

        for trial in range(1, N_max + 1):
            # Initialize centroids and run KMeans
            initial_centroids = initialize_centroids(data, k)
            kmeans = KMeans(n_clusters=k, init=initial_centroids, max_iter=100, n_init=1, random_state=42)
            kmeans.fit(data)

            final_centroids = kmeans.cluster_centers_
            final_labels = kmeans.labels_
            final_potential = compute_potential(data, final_labels, final_centroids)

            normalized_potential = final_potential / optimal_potential
            normalized_potentials.append(normalized_potential)

            N_stop = trial  # Update number of trials

            # After minimum number of trials, check early stopping condition
            if trial >= N_min:
                # Compute mean and standard deviation of normalized potentials observed so far
                mu = np.mean(normalized_potentials)
                sigma = np.std(normalized_potentials, ddof=1)
                # Avoid division by zero
                if sigma == 0:
                    sigma = 1e-8
                # Check early stopping condition
                stability_condition = abs(normalized_potential - mu) <= delta * sigma
                quality_condition = normalized_potential <= c

                if stability_condition and quality_condition:
                    success_flag = True
                    # Record the normalized potential at early stopping
                    normalized_potential_at_stop = normalized_potential
                    break  # Early stopping

        # If the loop completed without early stopping
        if not success_flag:
            # Even if early stopping did not occur, check if any trial achieved a constant-factor approximation
            success_flag = any(np.array(normalized_potentials) <= c)
            normalized_potential_at_stop = normalized_potentials[-1]  # Last normalized potential

        early_stop_counts.append(N_stop)
        success_flags.append(success_flag)
        normalized_potentials_at_stop.append(normalized_potential_at_stop)

        print(f"Early stopped after {N_stop} trials. Success: {success_flag}. Normalized potential at stop: {normalized_potential_at_stop:.4f}")

    # Compute statistics
    mean_N_stop = np.mean(early_stop_counts)
    std_N_stop = np.std(early_stop_counts, ddof=1)
    mean_normalized_potential = np.mean(normalized_potentials_at_stop)
    std_normalized_potential = np.std(normalized_potentials_at_stop, ddof=1)
    success_rate = np.mean(success_flags)

    # Compute standard error for N_stop
    SE_N_stop = std_N_stop / np.sqrt(N)

    # Compute confidence interval for mean N_stop
    z = 1.96  # For 95% confidence
    CI_lower_N_stop = mean_N_stop - z * SE_N_stop
    CI_upper_N_stop = mean_N_stop + z * SE_N_stop

    print(f"\nFor k = {k}:")
    print(f"Mean number of trials before early stopping: {mean_N_stop:.2f}")
    print(f"Standard deviation: {std_N_stop:.2f}")
    print(f"95% Confidence interval for mean number of trials: [{CI_lower_N_stop:.2f}, {CI_upper_N_stop:.2f}]")
    print(f"Success rate: {success_rate:.4f}")
    print(f"Mean normalized potential at early stopping: {mean_normalized_potential:.4f}")
    print(f"Standard deviation of normalized potential at early stopping: {std_normalized_potential:.4f}")

    # Store results for statistical analysis
    results[k] = {
        'early_stop_counts': early_stop_counts,
        'success_flags': success_flags,
        'normalized_potentials_at_stop': normalized_potentials_at_stop,
    }

# At this point, you have results dictionary containing the data for k=3,4,5
# Out:
# Running experiments for k = 3
# 1.0986122886681098
# Dataset 1/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 1.0000
# Dataset 2/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 1.0000
# Dataset 3/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 0.9999
# Dataset 4/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 1.0000
# Dataset 5/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 0.9926
# Dataset 6/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 0.9671
# Dataset 7/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 0.9776
# Dataset 8/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 0.9153
# Dataset 9/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 0.8208
# Dataset 10/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 0.7915
# Dataset 11/30 for k=3
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.9461
# Dataset 12/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 0.9532
# Dataset 13/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 0.9893
# Dataset 14/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 1.0000
# Dataset 15/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 0.9977
# Dataset 16/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 0.9947
# Dataset 17/30 for k=3
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.9610
# Dataset 18/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 1.0000
# Dataset 19/30 for k=3
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 1.0000
# Dataset 20/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 0.8290
# Dataset 21/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 0.9695
# Dataset 22/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 0.8181
# Dataset 23/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 0.9991
# Dataset 24/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 0.9985
# Dataset 25/30 for k=3
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.9990
# Dataset 26/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 1.0000
# Dataset 27/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 1.0000
# Dataset 28/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 0.9974
# Dataset 29/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 0.9961
# Dataset 30/30 for k=3
# Early stopped after 3 trials. Success: True. Normalized potential at stop: 1.0000
#
# For k = 3:
# Mean number of trials before early stopping: 3.13
# Standard deviation: 0.35
# 95% Confidence interval for mean number of trials: [3.01, 3.26]
# Success rate: 1.0000
# Mean normalized potential at early stopping: 0.9638
# Standard deviation of normalized potential at early stopping: 0.0630
#
# Running experiments for k = 4
# 1.3862943611198906
# Dataset 1/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.9955
# Dataset 2/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.9780
# Dataset 3/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.9567
# Dataset 4/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.9298
# Dataset 5/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.8484
# Dataset 6/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.9999
# Dataset 7/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.7564
# Dataset 8/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.9969
# Dataset 9/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 1.0000
# Dataset 10/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.8435
# Dataset 11/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.8427
# Dataset 12/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.9463
# Dataset 13/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.9863
# Dataset 14/30 for k=4
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.9618
# Dataset 15/30 for k=4
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.9848
# Dataset 16/30 for k=4
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.9475
# Dataset 17/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.9651
# Dataset 18/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.8606
# Dataset 19/30 for k=4
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.9964
# Dataset 20/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.8655
# Dataset 21/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.8791
# Dataset 22/30 for k=4
# Early stopped after 6 trials. Success: True. Normalized potential at stop: 0.9714
# Dataset 23/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.9977
# Dataset 24/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.9992
# Dataset 25/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.9025
# Dataset 26/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.9221
# Dataset 27/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.9700
# Dataset 28/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 0.9915
# Dataset 29/30 for k=4
# Early stopped after 4 trials. Success: True. Normalized potential at stop: 1.2202
# Dataset 30/30 for k=4
# Early stopped after 6 trials. Success: True. Normalized potential at stop: 0.9811
#
# For k = 4:
# Mean number of trials before early stopping: 4.27
# Standard deviation: 0.58
# 95% Confidence interval for mean number of trials: [4.06, 4.48]
# Success rate: 1.0000
# Mean normalized potential at early stopping: 0.9499
# Standard deviation of normalized potential at early stopping: 0.0811
#
# Running experiments for k = 5
# 1.6094379124341003
# Dataset 1/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 1.1637
# Dataset 2/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.9958
# Dataset 3/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.9204
# Dataset 4/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.9239
# Dataset 5/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 1.5815
# Dataset 6/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.9822
# Dataset 7/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.9996
# Dataset 8/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.9827
# Dataset 9/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.9091
# Dataset 10/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.8195
# Dataset 11/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.9857
# Dataset 12/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 1.3291
# Dataset 13/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.8999
# Dataset 14/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.8688
# Dataset 15/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 1.2392
# Dataset 16/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.8052
# Dataset 17/30 for k=5
# Early stopped after 6 trials. Success: True. Normalized potential at stop: 0.9760
# Dataset 18/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.8946
# Dataset 19/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 1.0265
# Dataset 20/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 1.4437
# Dataset 21/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 1.1872
# Dataset 22/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.9792
# Dataset 23/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.8520
# Dataset 24/30 for k=5
# Early stopped after 6 trials. Success: True. Normalized potential at stop: 0.9947
# Dataset 25/30 for k=5
# Early stopped after 6 trials. Success: True. Normalized potential at stop: 0.9865
# Dataset 26/30 for k=5
# Early stopped after 6 trials. Success: True. Normalized potential at stop: 0.9921
# Dataset 27/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.9957
# Dataset 28/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 1.0123
# Dataset 29/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.9403
# Dataset 30/30 for k=5
# Early stopped after 5 trials. Success: True. Normalized potential at stop: 0.9950
#
# For k = 5:
# Mean number of trials before early stopping: 5.13
# Standard deviation: 0.35
# 95% Confidence interval for mean number of trials: [5.01, 5.26]
# Success rate: 1.0000
# Mean normalized potential at early stopping: 1.0227
# Standard deviation of normalized potential at early stopping: 0.1766

# %%
# Statistical Analysis

# Collect early_stop_counts for each k
N_stop_k3 = results[3]['early_stop_counts']
N_stop_k4 = results[4]['early_stop_counts']
N_stop_k5 = results[5]['early_stop_counts']

# Perform one-way ANOVA on the number of trials before early stopping
F_statistic, p_value = stats.f_oneway(N_stop_k3, N_stop_k4, N_stop_k5)

print("\nOne-way ANOVA results on number of trials before early stopping:")
print(f"F-statistic: {F_statistic:.4f}")
print(f"p-value: {p_value:.4f}")

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("The differences in mean number of trials before early stopping across different k are statistically significant.")
    # Perform Tukey's HSD test
    # Prepare data for Tukey's HSD
    data_N_stop = N_stop_k3 + N_stop_k4 + N_stop_k5
    groups_N_stop = (['k=3'] * N) + (['k=4'] * N) + (['k=5'] * N)
    df_N_stop = pd.DataFrame({'N_stop': data_N_stop, 'Group': groups_N_stop})

    tukey_N_stop = pairwise_tukeyhsd(endog=df_N_stop['N_stop'], groups=df_N_stop['Group'], alpha=0.05)

    print("\nTukey's HSD test results for number of trials before early stopping:")
    print(tukey_N_stop)
else:
    print("No statistically significant differences were found in mean number of trials before early stopping across different k.")
# Out:
# One-way ANOVA results on number of trials before early stopping:
# F-statistic: 900.0000
# p-value: 0.0000
# The differences in mean number of trials before early stopping across different k are statistically significant.
#
# Tukey's HSD test results for number of trials before early stopping:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#    k=3    k=4      1.0   0.0 0.8876 1.1124   True
#    k=3    k=5      2.0   0.0 1.8876 2.1124   True
#    k=4    k=5      1.0   0.0 0.8876 1.1124   True
# -------------------------------------------------
